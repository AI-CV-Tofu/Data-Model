# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.35-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (3.9.2)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (1.14.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=1.8.0->ultralytics)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.35-py3-none-any.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 59.0 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 154.3 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 33.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 95.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 161.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 169.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 46.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 61.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 56.1 MB/s eta 0:00:00:00:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 55.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 59.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 57.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 49.4 MB/s eta 0:00:00:00:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 46.4 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 59.0 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 45.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# Installing collected packages: triton, sympy, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencv-python-4.10.0.84 sympy-1.13.1 torch-2.5.1 torchvision-0.20.1 triton-3.1.0 ultralytics-8.3.35 ultralytics-thop-2.0.12

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.7.1
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.8
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.116                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     cuda-cudart-11.8.89        |                0         197 KB  nvidia
#     cuda-cupti-11.8.87         |                0        25.3 MB  nvidia
#     cuda-libraries-11.8.0      |                0           1 KB  nvidia
#     cuda-nvrtc-11.8.89         |                0        19.1 MB  nvidia
#     cuda-nvtx-11.8.86          |                0          57 KB  nvidia
#     cuda-runtime-11.8.0        |                0           1 KB  nvidia
#     cuda-version-12.6          |                3          16 KB  nvidia
#     ffmpeg-7.1.0               | gpl_he2fd91e_702         9.8 MB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     libass-0.17.3              |       h1dc1e6a_0         130 KB  conda-forge
#     libcblas-3.9.0             |   16_linux64_mkl          12 KB  conda-forge
#     libcublas-11.11.3.6        |                0       364.0 MB  nvidia
#     libcufft-10.9.0.58         |                0       142.8 MB  nvidia
#     libcufile-1.11.1.6         |                0         899 KB  nvidia
#     libcusolver-11.4.1.48      |                0        96.5 MB  nvidia
#     libcusparse-11.7.5.86      |                0       176.3 MB  nvidia
#     liblapack-3.9.0            |   16_linux64_mkl          12 KB  conda-forge
#     liblapacke-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     libnpp-11.8.0.86           |                0       147.8 MB  nvidia
#     libnvjpeg-11.9.0.86        |                0         2.4 MB  nvidia
#     libopenvino-2024.4.0       |       hac27bb2_1         5.1 MB  conda-forge
#     libopenvino-auto-batch-plugin-2024.4.0|       h4d9b6c2_1         109 KB  conda-forge
#     libopenvino-auto-plugin-2024.4.0|       h4d9b6c2_1         232 KB  conda-forge
#     libopenvino-hetero-plugin-2024.4.0|       h3f63f65_1         193 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2024.4.0|       hac27bb2_1        11.5 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2024.4.0|       hac27bb2_1         8.5 MB  conda-forge
#     libopenvino-intel-npu-plugin-2024.4.0|       hac27bb2_1         781 KB  conda-forge
#     libopenvino-ir-frontend-2024.4.0|       h3f63f65_1         200 KB  conda-forge
#     libopenvino-onnx-frontend-2024.4.0|       he882d9a_1         1.5 MB  conda-forge
#     libopenvino-paddle-frontend-2024.4.0|       he882d9a_1         638 KB  conda-forge
#     libopenvino-pytorch-frontend-2024.4.0|       h5888daf_1         1.0 MB  conda-forge
#     libopenvino-tensorflow-frontend-2024.4.0|       h9718a47_1         1.2 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2024.4.0|       h5888daf_1         456 KB  conda-forge
#     librsvg-2.58.4             |       hc0ffecb_0         6.1 MB  conda-forge
#     libva-2.22.0               |       h8a09558_1         213 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     mkl-2022.1.0               |     h84fe81f_915       199.6 MB  conda-forge
#     mkl-devel-2022.1.0         |     ha770c72_916          25 KB  conda-forge
#     mkl-include-2022.1.0       |     h84fe81f_915         745 KB  conda-forge
#     mkl-service-2.4.0          |  py310h9263142_0          56 KB  conda-forge
#     mkl_fft-1.3.1              |  py310h1dd1467_4         193 KB  conda-forge
#     numexpr-2.7.3              |  py310hb5077e9_1         513 KB  conda-forge
#     ocl-icd-2.3.2              |       hd590300_1         133 KB  conda-forge
#     openh264-2.4.1             |       h59595ed_0         718 KB  conda-forge
#     pugixml-1.14               |       h59595ed_0         112 KB  conda-forge
#     pytorch-2.4.0              |py3.10_cuda11.8_cudnn9.1.0_0        1.53 GB  pytorch
#     pytorch-cuda-11.8          |       h7e8668a_6           7 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-2.4.0           |      py310_cu118         6.2 MB  pytorch
#     torchtriton-3.0.0          |            py310       233.4 MB  pytorch
#     torchvision-0.19.0         |      py310_cu118         8.3 MB  pytorch
#     wayland-protocols-1.37     |       hd8ed1ab_0          94 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        2.98 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda-cudart        nvidia/linux-64::cuda-cudart-11.8.89-0
#   cuda-cupti         nvidia/linux-64::cuda-cupti-11.8.87-0
#   cuda-libraries     nvidia/linux-64::cuda-libraries-11.8.0-0
#   cuda-nvrtc         nvidia/linux-64::cuda-nvrtc-11.8.89-0
#   cuda-nvtx          nvidia/linux-64::cuda-nvtx-11.8.86-0
#   cuda-runtime       nvidia/linux-64::cuda-runtime-11.8.0-0
#   cuda-version       nvidia/noarch::cuda-version-12.6-3
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.0-gpl_he2fd91e_702
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   libass             conda-forge/linux-64::libass-0.17.3-h1dc1e6a_0
#   libcublas          nvidia/linux-64::libcublas-11.11.3.6-0
#   libcufft           nvidia/linux-64::libcufft-10.9.0.58-0
#   libcufile          nvidia/linux-64::libcufile-1.11.1.6-0
#   libcurand          nvidia/linux-64::libcurand-10.3.7.77-0
#   libcusolver        nvidia/linux-64::libcusolver-11.4.1.48-0
#   libcusparse        nvidia/linux-64::libcusparse-11.7.5.86-0
#   libnpp             nvidia/linux-64::libnpp-11.8.0.86-0
#   libnvjpeg          nvidia/linux-64::libnvjpeg-11.9.0.86-0
#   libopenvino        conda-forge/linux-64::libopenvino-2024.4.0-hac27bb2_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2024.4.0-h4d9b6c2_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2024.4.0-h4d9b6c2_1
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2024.4.0-h3f63f65_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2024.4.0-hac27bb2_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2024.4.0-hac27bb2_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2024.4.0-hac27bb2_1
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2024.4.0-h3f63f65_1
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2024.4.0-he882d9a_1
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2024.4.0-he882d9a_1
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2024.4.0-h5888daf_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2024.4.0-h9718a47_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2024.4.0-h5888daf_1
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-hc0ffecb_0
#   libva              conda-forge/linux-64::libva-2.22.0-h8a09558_1
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.2-hd590300_1
#   openh264           conda-forge/linux-64::openh264-2.4.1-h59595ed_0
#   pugixml            conda-forge/linux-64::pugixml-1.14-h59595ed_0
#   pytorch            pytorch/linux-64::pytorch-2.4.0-py3.10_cuda11.8_cudnn9.1.0_0
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-11.8-h7e8668a_6
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/linux-64::torchaudio-2.4.0-py310_cu118
#   torchtriton        pytorch/linux-64::torchtriton-3.0.0-py310
#   torchvision        pytorch/linux-64::torchvision-0.19.0-py310_cu118
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.37-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#
# The following packages will be UPDATED:
#
#   openssl                                  3.3.2-hb9d3cd8_0 --> 3.4.0-hb9d3cd8_0
#
# The following packages will be DOWNGRADED:
#
#   blas                                            2.120-mkl --> 2.116-mkl
#   blas-devel                           3.9.0-20_linux64_mkl --> 3.9.0-16_linux64_mkl
#   libblas                              3.9.0-20_linux64_mkl --> 3.9.0-16_linux64_mkl
#   libcblas                             3.9.0-20_linux64_mkl --> 3.9.0-16_linux64_mkl
#   liblapack                            3.9.0-20_linux64_mkl --> 3.9.0-16_linux64_mkl
#   liblapacke                           3.9.0-20_linux64_mkl --> 3.9.0-16_linux64_mkl
#   llvm-openmp                             19.1.2-h024ca30_0 --> 15.0.7-h0cdce71_0
#   mkl                               2023.2.0-h84fe81f_50496 --> 2022.1.0-h84fe81f_915
#   mkl-devel                         2023.2.0-ha770c72_50496 --> 2022.1.0-ha770c72_916
#   mkl-include                       2023.2.0-h84fe81f_50496 --> 2022.1.0-h84fe81f_915
#   mkl-service                         2.4.1-py310h263290a_1 --> 2.4.0-py310h9263142_0
#   mkl_fft                            1.3.10-py310h0528b3e_1 --> 1.3.1-py310h1dd1467_4
#   numexpr                        2.10.1-mkl_py310h78a85ae_2 --> 2.7.3-py310hb5077e9_1
#
#
#
# Downloading and Extracting Packages:
# pytorch-2.4.0        | 1.53 GB   |                                       |   0%
# libcublas-11.11.3.6  | 364.0 MB  |                                       |   0%
#
# torchtriton-3.0.0    | 233.4 MB  |                                       |   0%
#
#
# mkl-2022.1.0         | 199.6 MB  |                                       |   0%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  |                                       |   0%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  |                                       |   0%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  |                                       |   0%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   |                                       |   0%
#
#
#
#
#
#
#
# cuda-cupti-11.8.87   | 25.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.0         | 9.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.19.0   | 8.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.0     | 6.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.4.0 | 5.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    |                                       |   0%
# pytorch-2.4.0        | 1.53 GB   |                                       |   0% [A
# libcublas-11.11.3.6  | 364.0 MB  | 1                                     |   0%
#
# torchtriton-3.0.0    | 233.4 MB  |                                       |   0%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | 2                                     |   1%
#
#
# pytorch-2.4.0        | 1.53 GB   | 1                                     |   0%
#
# torchtriton-3.0.0    | 233.4 MB  | 8                                     |   2%
# libcublas-11.11.3.6  | 364.0 MB  | 6                                     |   2%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #3                                    |   4%
#
#
# pytorch-2.4.0        | 1.53 GB   | 2                                     |   1%
#
# torchtriton-3.0.0    | 233.4 MB  | #7                                    |   5%
# libcublas-11.11.3.6  | 364.0 MB  | #1                                    |   3%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ##4                                   |   7%
#
#
# pytorch-2.4.0        | 1.53 GB   | 3                                     |   1%
#
# torchtriton-3.0.0    | 233.4 MB  | ##6                                   |   7%
# libcublas-11.11.3.6  | 364.0 MB  | #7                                    |   5%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ###6                                  |  10%
#
#
# pytorch-2.4.0        | 1.53 GB   | 5                                     |   1%
#
# torchtriton-3.0.0    | 233.4 MB  | ###5                                  |  10%
# libcublas-11.11.3.6  | 364.0 MB  | ##2                                   |   6%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ####8                                 |  13%
#
#
# pytorch-2.4.0        | 1.53 GB   | 6                                     |   2%
# libcublas-11.11.3.6  | 364.0 MB  | ##8                                   |   8%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ######                                |  16%
#
#
# mkl-2022.1.0         | 199.6 MB  | #####8                                |  16%
#
# pytorch-2.4.0        | 1.53 GB   | 8                                     |   2%
# libcublas-11.11.3.6  | 364.0 MB  | ###4                                  |   9%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #######3                              |  20%
#
#
# mkl-2022.1.0         | 199.6 MB  | #######                               |  19%
#
# torchtriton-3.0.0    | 233.4 MB  | #####                                 |  14%
# libcublas-11.11.3.6  | 364.0 MB  | ####                                  |  11%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ########6                             |  23%
#
#
# pytorch-2.4.0        | 1.53 GB   | 9                                     |   3%
#
# torchtriton-3.0.0    | 233.4 MB  | #####7                                |  16%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #########9                            |  27%
#
#
# pytorch-2.4.0        | 1.53 GB   | #1                                    |   3%
# libcublas-11.11.3.6  | 364.0 MB  | ####6                                 |  12%
#
# torchtriton-3.0.0    | 233.4 MB  | ######4                               |  17%
#
#
# mkl-2022.1.0         | 199.6 MB  | ##########7                           |  29%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ###########1                          |  30%
# pytorch-2.4.0        | 1.53 GB   | #2                                    |   3%
#
# torchtriton-3.0.0    | 233.4 MB  | #######3                              |  20%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ############3                         |  33%
# libcublas-11.11.3.6  | 364.0 MB  | #####7                                |  16%
#
#
# pytorch-2.4.0        | 1.53 GB   | #4                                    |   4%
#
# torchtriton-3.0.0    | 233.4 MB  | ########                              |  22%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #############6                        |  37%
# libcublas-11.11.3.6  | 364.0 MB  | ######3                               |  17%
#
#
# pytorch-2.4.0        | 1.53 GB   | #5                                    |   4%
#
# torchtriton-3.0.0    | 233.4 MB  | ########8                             |  24%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ##############8                       |  40%
# libcublas-11.11.3.6  | 364.0 MB  | ######9                               |  19%
#
#
# pytorch-2.4.0        | 1.53 GB   | #6                                    |   5%
#
# torchtriton-3.0.0    | 233.4 MB  | #########7                            |  26%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ################1                     |  44%
# pytorch-2.4.0        | 1.53 GB   | #8                                    |   5%
#
#
# mkl-2022.1.0         | 199.6 MB  | ###############2                      |  41%
#
# torchtriton-3.0.0    | 233.4 MB  | ##########6                           |  29%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #################3                    |  47%
# pytorch-2.4.0        | 1.53 GB   | #9                                    |   5%
#
#
# mkl-2022.1.0         | 199.6 MB  | ################3                     |  44%
#
# torchtriton-3.0.0    | 233.4 MB  | ###########6                          |  31%
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##1                                   |   6%
#
#
# mkl-2022.1.0         | 199.6 MB  | #################6                    |  48%
# libcublas-11.11.3.6  | 364.0 MB  | ########6                             |  23%
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##3                                   |   6%
#
#
# mkl-2022.1.0         | 199.6 MB  | ###################4                  |  52%
# libcublas-11.11.3.6  | 364.0 MB  | #########1                            |  25%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #####################8                |  59%
#
#
# mkl-2022.1.0         | 199.6 MB  | #####################4                |  58%
#
# torchtriton-3.0.0    | 233.4 MB  | ############4                         |  34%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | #######################2              |  63%
# libcublas-11.11.3.6  | 364.0 MB  | #########6                            |  26%
#
# pytorch-2.4.0        | 1.53 GB   | ##4                                   |   7%
#
#
# mkl-2022.1.0         | 199.6 MB  | #######################               |  62%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ########################9             |  67%
# libcublas-11.11.3.6  | 364.0 MB  | ##########1                           |  27%
#
# pytorch-2.4.0        | 1.53 GB   | ##6                                   |   7%
#
#
# mkl-2022.1.0         | 199.6 MB  | ########################3             |  66%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ##########################8           |  72%
# pytorch-2.4.0        | 1.53 GB   | ##7                                   |   7%
#
# torchtriton-3.0.0    | 233.4 MB  | ################2                     |  44%
#
#
# mkl-2022.1.0         | 199.6 MB  | #########################6            |  69%
# libcublas-11.11.3.6  | 364.0 MB  | ##########9                           |  30%
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##8                                   |   8%
#
# torchtriton-3.0.0    | 233.4 MB  | #################1                    |  46%
#
#
# mkl-2022.1.0         | 199.6 MB  | ##########################9           |  73%
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##9                                   |   8%
#
# torchtriton-3.0.0    | 233.4 MB  | ##################3                   |  50%
# libcublas-11.11.3.6  | 364.0 MB  | ###########3                          |  31%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ################################1     |  87%
#
#
# pytorch-2.4.0        | 1.53 GB   | ###1                                  |   8%
# libcublas-11.11.3.6  | 364.0 MB  | ###########8                          |  32%
#
# torchtriton-3.0.0    | 233.4 MB  | ###################3                  |  52%
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###2                                  |   9%
# libcublas-11.11.3.6  | 364.0 MB  | ############2                         |  33%
#
# torchtriton-3.0.0    | 233.4 MB  | ####################3                 |  55%
#
#
# pytorch-2.4.0        | 1.53 GB   | ###4                                  |   9%
# libcublas-11.11.3.6  | 364.0 MB  | ############8                         |  35%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ###################################4  |  96%
#
# torchtriton-3.0.0    | 233.4 MB  | #####################2                |  57%
#
#
# pytorch-2.4.0        | 1.53 GB   | ###5                                  |  10%
# libcublas-11.11.3.6  | 364.0 MB  | #############3                        |  36%
#
# torchtriton-3.0.0    | 233.4 MB  | ######################1               |  60%
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ####################################9 | 100%
#
#
# pytorch-2.4.0        | 1.53 GB   | ###7                                  |  10%
# libcublas-11.11.3.6  | 364.0 MB  | #############8                        |  37%
#
# torchtriton-3.0.0    | 233.4 MB  | #######################6              |  64%
#
#
# pytorch-2.4.0        | 1.53 GB   | ###9                                  |  11%
# libcublas-11.11.3.6  | 364.0 MB  | ##############3                       |  39%
#
# torchtriton-3.0.0    | 233.4 MB  | ########################6             |  67%
#
#
# pytorch-2.4.0        | 1.53 GB   | ####1                                 |  11%
# libcublas-11.11.3.6  | 364.0 MB  | ###############2                      |  41%
#
# torchtriton-3.0.0    | 233.4 MB  | #########################7            |  70%
#
#
# pytorch-2.4.0        | 1.53 GB   | ####2                                 |  12%
# libcublas-11.11.3.6  | 364.0 MB  | ###############9                      |  43%
#
# pytorch-2.4.0        | 1.53 GB   | ####5                                 |  12%
# libcublas-11.11.3.6  | 364.0 MB  | ################5                     |  45%
#
#
# mkl-2022.1.0         | 199.6 MB  | ###################################4  |  96%
#
# pytorch-2.4.0        | 1.53 GB   | ####8                                 |  13%
#
# torchtriton-3.0.0    | 233.4 MB  | ############################9         |  78%
#
#
# pytorch-2.4.0        | 1.53 GB   | #####1                                |  14%
# libcublas-11.11.3.6  | 364.0 MB  | #################                     |  46%
#
# pytorch-2.4.0        | 1.53 GB   | #####3                                |  14%
# libcublas-11.11.3.6  | 364.0 MB  | #################5                    |  47%
#
# pytorch-2.4.0        | 1.53 GB   | #####5                                |  15%
# pytorch-2.4.0        | 1.53 GB   | #####8                                |  16%
#
# torchtriton-3.0.0    | 233.4 MB  | ##################################    |  92%
# libcublas-11.11.3.6  | 364.0 MB  | ##################5                   |  50%
# libcublas-11.11.3.6  | 364.0 MB  | ###################5                  |  53%
#
# pytorch-2.4.0        | 1.53 GB   | ######                                |  16%
# libcublas-11.11.3.6  | 364.0 MB  | ####################2                 |  55%
#
# pytorch-2.4.0        | 1.53 GB   | ######2                               |  17%
# pytorch-2.4.0        | 1.53 GB   | ######5                               |  18%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  |                                       |   0%
# libcublas-11.11.3.6  | 364.0 MB  | #####################5                |  58%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ######7                               |  18%
# libcublas-11.11.3.6  | 364.0 MB  | ######################1               |  60%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ######9                               |  19%
# libcublas-11.11.3.6  | 364.0 MB  | ######################9               |  62%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #######1                              |  19%
# libcublas-11.11.3.6  | 364.0 MB  | #######################6              |  64%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #######3                              |  20%
# libcublas-11.11.3.6  | 364.0 MB  | ########################3             |  66%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ########8                             |  24%
# pytorch-2.4.0        | 1.53 GB   | #######5                              |  20%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ##########7                           |  29%
# libcublas-11.11.3.6  | 364.0 MB  | #########################7            |  69%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #######7                              |  21%
# libcublas-11.11.3.6  | 364.0 MB  | ##########################4           |  71%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #######9                              |  21%
# libcublas-11.11.3.6  | 364.0 MB  | ###########################           |  73%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ########                              |  22%
# libcublas-11.11.3.6  | 364.0 MB  | ###########################9          |  75%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ########2                             |  22%
# libcublas-11.11.3.6  | 364.0 MB  | ############################6         |  77%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ########4                             |  23%
# libcublas-11.11.3.6  | 364.0 MB  | #############################3        |  79%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ########5                             |  23%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ##########################2           |  71%
# pytorch-2.4.0        | 1.53 GB   | ########7                             |  24%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ############################3         |  77%
# pytorch-2.4.0        | 1.53 GB   | ########8                             |  24%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ###############################5      |  85%
# pytorch-2.4.0        | 1.53 GB   | #########                             |  24%
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #########1                            |  25%
# pytorch-2.4.0        | 1.53 GB   | #########3                            |  25%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  |                                       |   0%
# pytorch-2.4.0        | 1.53 GB   | #########5                            |  26%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##1                                   |   6%
# libcublas-11.11.3.6  | 364.0 MB  | ################################9     |  89%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #########6                            |  26%
# pytorch-2.4.0        | 1.53 GB   | #########8                            |  27%
# libcublas-11.11.3.6  | 364.0 MB  | #################################9    |  92%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #########9                            |  27%
# libcublas-11.11.3.6  | 364.0 MB  | ##################################6   |  94%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##########1                           |  27%
# libcublas-11.11.3.6  | 364.0 MB  | ###################################2  |  95%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##########3                           |  28%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###########7                          |  32%
# pytorch-2.4.0        | 1.53 GB   | ##########4                           |  28%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #############6                        |  37%
# pytorch-2.4.0        | 1.53 GB   | ##########6                           |  29%
# libcublas-11.11.3.6  | 364.0 MB  | ####################################9 | 100%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##########8                           |  29%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #################6                    |  48%
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##########9                           |  30%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###################5                  |  53%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##4                                   |   7%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####8                                 |  13%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########1                          |  30%
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########2                          |  30%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########1                            |  25%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########3                          |  31%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###########1                          |  30%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########4                          |  31%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #############1                        |  36%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########6                          |  31%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###############2                      |  41%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##########################8           |  73%
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########7                          |  32%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########8                          |  32%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####################                  |  54%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #############################4        |  79%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###########9                          |  32%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######################                |  60%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##############################5       |  83%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############1                         |  33%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######################8              |  64%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###############################7      |  86%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############2                         |  33%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########################6            |  69%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ################################9     |  89%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############3                         |  33%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###########################5          |  75%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##################################1   |  92%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############4                         |  34%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #############################5        |  80%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###################################4  |  96%
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############5                         |  34%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###############################7      |  86%
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############7                         |  34%
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############8                         |  35%
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ############9                         |  35%
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.19.0   | 8.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.19.0   | 8.3 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.0     | 6.2 MB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.4.0 | 5.1 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.0 MB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 1.53 GB   | ####################################8 | 100% [A
#
#
#
# libcusparse-11.7.5.8 | 176.3 MB  | ##################################### | 100%
#
# torchtriton-3.0.0    | 233.4 MB  | ##################################### | 100%
#
#
# mkl-2022.1.0         | 199.6 MB  | ##################################### | 100%
#
#
#
#
#
#
#
# cuda-cupti-11.8.87   | 25.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.0         | 9.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##################################### | 100%
#
#
#
#
# libnpp-11.8.0.86     | 147.8 MB  | ##################################### | 100%
# libnpp-11.8.0.86     | 147.8 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.0     | 6.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.19.0   | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.4.0 | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.4.0 | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##################################### | 100%
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##################################### | 100%
# pytorch-2.4.0        | 1.53 GB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
# /
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import torch

# YOLO 모델 로드
model = YOLO("../yolo11s.pt")

# 디바이스 설정
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# PyTorch에서 디바이스 출력
print("gpu :", device)
# Out:
# WARNING ⚠️ torchvision==0.20 is incompatible with torch==2.4.
# Run 'pip install torchvision==0.19' to fix torchvision or 'pip install -U torch torchvision' to update both.
# For a full compatibility table see https://github.com/pytorch/vision#installation
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/ec2-user/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# gpu : cuda

# %%
model.train(
    data="/7class_640_re",  # 데이터 경로
    epochs=50,  # 학습 epoch 수
    imgsz=640,  # 이미지 크기
    batch=16,  # 배치 크기
    device=0,  # GPU (device=0은 첫 번째 GPU를 사용)
    project="yolov11s",  # 프로젝트 이름
    name="7class_640_re"  # 실험 이름 (결과를 구분하기 위함)
)
# Out:
# Ultralytics 8.3.35 🚀 Python-3.10.15 torch-2.4.0 CUDA:0 (Tesla T4, 14918MiB)
# engine/trainer: task=detect, mode=train, model=../yolo11s.pt, data=../7class_640_re/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=yolov11s, name=7class_640_re3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=yolov11s/7class_640_re3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/ultralytics/engine/trainer.py:562, in BaseTrainer.get_dataset(self)
#     556 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     557     "detect",
#     558     "segment",
#     559     "pose",
#     560     "obb",
#     561 }:
# --> 562     data = check_det_dataset(self.args.data)
#     563     if "yaml_file" in data:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/ultralytics/data/utils.py:329, in check_det_dataset(dataset, autodownload)
#     328     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 329     raise FileNotFoundError(m)
#     330 t = time.time()
#
# FileNotFoundError:
# Dataset '../7class_640_re/data.yaml' images not found ⚠️, missing path '/home/ec2-user/SageMaker/yuna/7class_640_re/7class_640_re/valid/images'
# Note dataset download directory is '/home/ec2-user/SageMaker/yuna/datasets'. You can update this in '/home/ec2-user/.config/Ultralytics/settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.train(
#       2     data="../7class_640_re/data.yaml",  # 데이터 경로
#       3     epochs=50,  # 학습 epoch 수
#       4     imgsz=640,  # 이미지 크기
#       5     batch=16,  # 배치 크기
#       6     device=0,  # GPU (device=0은 첫 번째 GPU를 사용)
#       7     project="yolov11s",  # 프로젝트 이름
#       8     name="7class_640_re"  # 실험 이름 (결과를 구분하기 위함)
#       9 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/ultralytics/engine/model.py:796, in Model.train(self, trainer, **kwargs)
#     793 if args.get("resume"):
#     794     args["resume"] = self.ckpt_path
# --> 796 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     797 if not args.get("resume"):  # manually set model only if not resuming
#     798     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/ultralytics/engine/trainer.py:133, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     131 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     132 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 133     self.trainset, self.testset = self.get_dataset()
#     134 self.ema = None
#     136 # Optimization utils init
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/ultralytics/engine/trainer.py:566, in BaseTrainer.get_dataset(self)
#     564             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     565 except Exception as e:
# --> 566     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     567 self.data = data
#     568 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset '../7class_640_re/data.yaml' error ❌
# Dataset '../7class_640_re/data.yaml' images not found ⚠️, missing path '/home/ec2-user/SageMaker/yuna/7class_640_re/7class_640_re/valid/images'
# Note dataset download directory is '/home/ec2-user/SageMaker/yuna/datasets'. You can update this in '/home/ec2-user/.config/Ultralytics/settings.json'
